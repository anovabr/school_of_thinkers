# %% [markdown]
# # School of Thinkers — DP (person level data, database extraction 2026-08-23)
#
# Author: Luís Anunciação
#
# - Source of truth: `Data/Official/` (the website's general export is lossy and was discarded).
# - Recoding follows `EP_codebook.csv`; numeric `_num` columns are created next to the original text.
# - Default sample: the 3 real municipal schools (O Semeador, Futuro Brilhante, Marton Lucca). Records from Escola Modelo (the platform's demonstration school) and from the Secretaria de Educação are excluded at the end of cleaning.
# - Single output: `ep.rds` with df_st (students), df_par (families), df_t (teachers), df_dy (dyads).
# - After the output, the notebook builds the Relatório 2 tables (descriptive tables, school comparison and the CFA supplement). The Paper 1 analyses are in the DA notebook.

# %%
# DP §1 - load the 4 CSVs (UTF-8 with BOM), tag the instrument, standardize metadata
pacman::p_load(tidyverse)

raw <- imap(c(students = "Official/EP_alunos_saude_emocional.csv",
              parents = "Official/EP_pais_saude_emocional_familia.csv",
              teachers_practice = "Official/EP_professores_pratica_pedagogica.csv",
              teachers_qol = "Official/EP_professores_qualidade_vida_saude_mental.csv"),
            \(f, inst) read_csv(file.path("../Data", f), show_col_types = FALSE) |>
              mutate(instrument = inst) |>
              select(-survey_title, -target_audience, -respondent_type))
map(raw, dim) |> as_tibble()
# Out:
#   students parents teachers_practice teachers_qol
# 1 748      915     97                122
# 2  35       46     44                 68

# %%
# DP §2 - cleaning and recoding; builds df_st, df_par, df_t, df_dy

# clean_rows(d, name_col, birth_col): keeps _status == completed, removes test names and,
# if birth_col is given, impossible birth dates (year >= 2026); prints rows removed per rule
clean_rows <- function(d, name_col, birth_col = NULL) {
  n0 <- nrow(d)
  d1 <- filter(d, `_status` == "completed")
  d2 <- filter(d1, !str_detect(replace_na(.data[[name_col]], ""), regex("teste|ttyy|tr5rrt", ignore_case = TRUE)))
  d3 <- if (is.null(birth_col)) d2 else filter(d2, coalesce(year(as_date(.data[[birth_col]])), 0) < 2026)
  cat(sprintf("%-18s raw %4d | -draft %d | -test name %d | -birth>=2026 %d | final %d\n",
              d$instrument[1], n0, n0 - nrow(d1), nrow(d1) - nrow(d2), nrow(d2) - nrow(d3), nrow(d3)))
  d3
}

# recode_items(d, cols, map): creates <col>_num keeping the original text; map = named vector or function
recode_items <- function(d, cols, map) {
  f <- if (is.function(map)) map else \(v) unname(map[v])
  mutate(d, across(all_of(cols), \(v) f(v), .names = "{.col}_num"))
}

first_digit <- \(v) as.numeric(str_extract(v, "\\d"))  # anchor digit (emoji or parentheses)
likert_freq <- c(Nunca = 1, Raramente = 2, `Às vezes` = 3, Frequentemente = 4, Sempre = 5)
likert_freq_upper <- c(NUNCA = 1, RARAMENTE = 2, `ÀS VEZES` = 3, FREQUENTEMENTE = 4, SEMPRE = 5)
yes_no <- c(Sim = 1, `Não` = 0)

target_schools <- c("O SEMEADOR", "Futuro Brilhante", "Marton Lucca")
# keep_schools(d): keeps only the 3 real municipal schools (Escola Modelo = platform demo
# school; Secretaria de Educação is not a school); prints what was removed
keep_schools <- function(d, col = "school_name") {
  removed <- d |> filter(!(.data[[col]] %in% target_schools)) |> count(.data[[col]])
  if (nrow(removed) > 0) {cat("  removed (outside the 3 schools): "); cat(sprintf("%s = %d; ", removed[[1]], removed$n)); cat("\n")}
  filter(d, .data[[col]] %in% target_schools)
}

cat("Cleaning (rows removed per rule):\n")
df_st <- clean_rows(raw$students, "respondent_name") |>
  keep_schools() |>
  recode_items(paste0("behavior_matrix.", 1:11), first_digit) |>
  recode_items(paste0("yes_no_questions.q", 12:18), yes_no) |>
  recode_items("demographics.age", \(v) as.numeric(str_extract(v, "\\d+")))

# caregiver birth dates with year >= 2026 (24 cases) are typos, not test rows: kept
df_par <- clean_rows(raw$parents, "respondent_name") |>
  keep_schools() |>
  recode_items(paste0("behavior_matrix.", 1:11), first_digit) |>
  recode_items(paste0("yes_no_questions.q", 12:18), yes_no)

df_t <- clean_rows(raw$teachers_practice, "demographics.full_name", "demographics.birth_date") |>
  recode_items(paste0("matrix_1.", 5:14), likert_freq) |>
  recode_items(paste0("matrix_2.", 15:25), first_digit) |>  # 0 = 'cannot say' (outside the 1-4 continuum; treat as missing in analysis)
  recode_items("initial_questions.q_1", yes_no) |>
  recode_items("initial_questions.q_2", likert_freq) |>
  full_join(clean_rows(raw$teachers_qol, "demographics.full_name", "demographics.birth_date") |>
              mutate(school_name = coalesce(school_name, `demographics.school`)) |>
              recode_items(paste0("questions_matrix.", 1:49), likert_freq_upper),
            by = "respondent_id", suffix = c("_pratica", "_qualidade")) |>
  mutate(school_name = coalesce(school_name_pratica, school_name_qualidade),
         full_name = coalesce(`demographics.full_name_pratica`, `demographics.full_name_qualidade`),
         has_pratica = !is.na(response_id_pratica),
         has_qualidade = !is.na(response_id_qualidade)) |>
  keep_schools()

# respondent_id is the child's ID in both emotional health inventories -> dyad
df_dy <- inner_join(df_st, df_par, by = "respondent_id", suffix = c("_aluno", "_familia"))
# Out:
# Cleaning (rows removed per rule):
# students           raw  748 | -draft 3 | -test name 0 | -birth>=2026 0 | final 745
#   removed (outside the 3 schools): Escola Modelo = 4;
# parents            raw  915 | -draft 1 | -test name 0 | -birth>=2026 0 | final 914
#   removed (outside the 3 schools): Escola Modelo = 2;
# teachers_practice  raw   97 | -draft 1 | -test name 0 | -birth>=2026 5 | final 91
# teachers_qol       raw  122 | -draft 0 | -test name 4 | -birth>=2026 7 | final 111
#   removed (outside the 3 schools): Escola Modelo = 3;  Secretaria de Educação = 6;

# %%
# DP §3 - data quality report: n per school, item missingness, duplicates
quality_report <- function(d, label, school = "school_name") {
  cat(sprintf("\n--- %s: n = %d\n", label, nrow(d)))
  print(count(d, school = .data[[school]], sort = TRUE))
  d |>
    summarise(across(ends_with("_num"), \(v) sum(is.na(v)))) |>
    pivot_longer(everything(), names_to = "item", values_to = "n_missing") |>
    filter(n_missing > 0) |>
    arrange(desc(n_missing)) |>
    (\(m) {cat(sprintf("items with missing: %d\n", nrow(m))); if (nrow(m) > 0) print(head(m, 10))})()
  cat(sprintf("duplicated respondent_id: %d\n", sum(duplicated(d$respondent_id))))
}

quality_report(df_st, "df_st")
quality_report(df_par, "df_par")
quality_report(df_t, "df_t (people; item missingness is structural for those who answered only 1 survey; 17 QoL respondents stopped mid inventory)")
cat(sprintf("\n--- df_dy: n = %d (student and family completed for the same child)\n", nrow(df_dy)))
print(count(df_dy, school_name_aluno, sort = TRUE))
cat(sprintf("teachers in both surveys: %d\n", sum(df_t$has_pratica & df_t$has_qualidade)))
# Out:
# --- df_st: n = 741
# # A tibble: 3 × 2
#   school               n
#   <chr>            <int>
# 1 O SEMEADOR         421
# 2 Futuro Brilhante   241
# 3 Marton Lucca        79
# items with missing: 0
# duplicated respondent_id: 0
# --- df_par: n = 912
# # A tibble: 3 × 2
#   school               n
#   <chr>            <int>
# 1 O SEMEADOR         648
# 2 Futuro Brilhante   184
# 3 Marton Lucca        80
# items with missing: 0
# duplicated respondent_id: 0
# --- df_t (people; item missingness is structural for those who answered only 1 survey; 17 QoL respondents stopped mid inventory): n = 111
# # A tibble: 3 × 2
#   school               n
#   <chr>            <int>
# 1 O SEMEADOR          41
# 2 Marton Lucca        36
# 3 Futuro Brilhante    34
# items with missing: 72
# # A tibble: 10 × 2
#    item            n_missing
#    <chr>               <int>
#  1 matrix_1.5_num         21
#  2 matrix_1.6_num         21
#  3 matrix_1.7_num         21
#  4 matrix_1.8_num         21
#  5 matrix_1.9_num         21
#  6 matrix_1.10_num        21
#  7 matrix_1.11_num        21
#  8 matrix_1.12_num        21
#  9 matrix_1.13_num        21
# 10 matrix_1.14_num        21
# duplicated respondent_id: 0
# --- df_dy: n = 406 (student and family completed for the same child)
# # A tibble: 3 × 2
#   school_name_aluno     n
#   <chr>             <int>
# 1 O SEMEADOR          284
# 2 Futuro Brilhante     92
# 3 Marton Lucca         30
# teachers in both surveys: 81

# %%
# DP §4 - validation against expected totals and single output
tribble(
  ~check, ~ok,
  "raw: students 748", nrow(raw$students) == 748,
  "raw: parents 915", nrow(raw$parents) == 915,
  "raw: practice 97", nrow(raw$teachers_practice) == 97,
  "raw: qol 122", nrow(raw$teachers_qol) == 122,
  "completed: students 745", sum(raw$students$`_status` == "completed") == 745,
  "completed: practice 96", sum(raw$teachers_practice$`_status` == "completed") == 96,
  "completed: qol 122", sum(raw$teachers_qol$`_status` == "completed") == 122,
  "raw student-parent overlap 410", length(intersect(raw$students$respondent_id, raw$parents$respondent_id)) == 410,
  "final: students 741", nrow(df_st) == 741,
  "final: parents 912", nrow(df_par) == 912,
  "final: teachers 111", nrow(df_t) == 111,
  "final: dyads 406", nrow(df_dy) == 406
) |>
  (\(v) {print(as.data.frame(v)); stopifnot(all(v$ok)); v})() |>
  invisible()

cat(sprintf("completed: parents = %d\n", sum(raw$parents$`_status` == "completed")))

saveRDS(list(df_st = df_st, df_par = df_par,
             df_t = df_t, df_dy = df_dy), "ep.rds")
cat("Saved: ep.rds\n")
# Out:
#                             check   ok
# 1               raw: students 748 TRUE
# 2                raw: parents 915 TRUE
# 3                raw: practice 97 TRUE
# 4                    raw: qol 122 TRUE
# 5         completed: students 745 TRUE
# 6          completed: practice 96 TRUE
# 7              completed: qol 122 TRUE
# 8  raw student-parent overlap 410 TRUE
# 9             final: students 741 TRUE
# 10             final: parents 912 TRUE
# 11            final: teachers 111 TRUE
# 12               final: dyads 406 TRUE
# completed: parents = 914
# Saved: ep.rds

# %% [markdown]
# ## Relatório 2 tables

# %%
# Report setup: codebook, enrollment list (Table 1 denominator) and the formatters used below
pacman::p_load(readxl, lavaan, effectsize, broom)
cb <- read_csv("../Data/Official/EP_codebook.csv", show_col_types = FALSE)
roster <- read_xlsx("../Data/Old/Raw website export 2026-08-23/exportacao_geral_2026-08-23.xlsx", skip = 2,
                    col_names = paste0("c", 1:147), col_types = "text") |>
  select(escola = c1, turma = c2)

# formatters: M (SD), % yes, n (%)
msd <- \(v) sprintf("%.2f (%.2f)", mean(v, na.rm = TRUE), sd(v, na.rm = TRUE))
psim <- \(v) sprintf("%.1f%%", 100 * mean(v, na.rm = TRUE))
npct <- \(n, d) sprintf("%d (%.1f%%)", n, 100 * n / d)

stopifnot(nrow(roster) == 1694)

# %% [markdown]
# ### Table 1 — Responses per school
#
# Coverage of each respondent group against enrolment; sets the denominator for every percentage reported below.

# %%
# Table 1 - responses per school (denominator: enrolled students); dyads and triads
roster |>
  count(escola, name = "N") |>
  full_join(count(df_st, escola = school_name, name = "aluno"), by = "escola") |>
  full_join(count(df_par, escola = school_name, name = "familia"), by = "escola") |>
  full_join(count(df_t, escola = school_name, name = "professor"), by = "escola") |>
  bind_rows(tibble(escola = "Total", N = nrow(roster), aluno = nrow(df_st),
                   familia = nrow(df_par), professor = nrow(df_t))) |>
  mutate(across(c(aluno, familia, professor), \(x) replace_na(x, 0L)),
         `Student n (%)` = if_else(is.na(N), "—", npct(aluno, N)),
         `Family n (%)` = if_else(is.na(N), "—", npct(familia, N))) |>
  select(School = escola, `N enrolled` = N, `Student n (%)`, `Family n (%)`, `Teacher, n` = professor) |>
  print(n = Inf)

# dyads per school and triads (dyad in a class evaluated by a Practice teacher)
count(df_dy, school_name_aluno, name = "dyads") |> print()
df_dy |>
  filter(class_id_aluno %in% df_t$demographics.class_evaluated) |>
  count(school_name_aluno, name = "triads") |>
  (\(x) {print(x); cat("total triads:", sum(x$triads), "\n")})()
# Out:
# # A tibble: 5 × 5
#   School           `N enrolled` `Student n (%)` `Family n (%)` `Teacher, n`
#   <chr>                   <int> <chr>           <chr>                 <int>
# 1 Escola Modelo              13 0 (0.0%)        0 (0.0%)                  0
# 2 Futuro Brilhante          518 241 (46.5%)     184 (35.5%)              34
# 3 Marton Lucca              202 79 (39.1%)      80 (39.6%)               36
# 4 O SEMEADOR                961 421 (43.8%)     648 (67.4%)              41
# 5 Total                    1694 741 (43.7%)     912 (53.8%)             111
# # A tibble: 3 × 2
#   school_name_aluno dyads
#   <chr>             <int>
# 1 Futuro Brilhante     92
# 2 Marton Lucca         30
# 3 O SEMEADOR          284
# # A tibble: 3 × 2
#   school_name_aluno triads
#   <chr>              <int>
# 1 Futuro Brilhante      76
# 2 Marton Lucca          30
# 3 O SEMEADOR           213
# total triads: 319

# %% [markdown]
# ### Table 2 — Respondent demographics
#
# Describes who answered in each group; source of manuscript Table 1.

# %%
# Table 2 - respondent demographics (APA format: label row, indented categories)
# count_pct(data, var, label): header row + indented n (%) frequencies
count_pct <- function(data, var, label) data |>
  count(category = replace_na({{var}}, "Not informed")) |>
  transmute(Characteristic = paste0("  ", category), Value = npct(n, sum(n))) |>
  (\(x) bind_rows(tibble(Characteristic = label, Value = ""), x))()

bind_rows(
  tibble(Characteristic = sprintf("Responding students (n = %d)", nrow(df_st)), Value = ""),
  # age: M/SD over valid values (na.rm)
  df_st |> summarise(Value = msd(demographics.age_num)) |> mutate(Characteristic = "  Age in years, M (SD)"),
  df_st |> mutate(sexo = if_else(demographics.gender %in% c("Outros", "Prefiro não informar"),
                                          "Other / prefer not to say", demographics.gender)) |> count_pct(sexo, "Sex"),
  df_st |> count_pct(demographics.household_size, "People at home (excluding the student)"),
  tibble(Characteristic = sprintf("Responding families (n = %d)", nrow(df_par)), Value = ""),
  df_par |> count_pct(family_structure.family_income, "Monthly family income"),
  df_par |> count_pct(family_structure.household_size, "People at home (excluding the respondent)"),
  df_par |> count_pct(child_development.premature, "Premature birth of the child"),
  df_par |> mutate(diag = if_else(str_detect(replace_na(child_development.diagnoses, ""),
                                                    "DI|TDAH|Dislexia|Discalculia|TEA"),
                                         "Any diagnosis", "No diagnosis")) |> count_pct(diag, "Child diagnosis"),
  tibble(Characteristic = sprintf("Responding teachers (n = %d)", nrow(df_t)), Value = ""),
  df_t |> mutate(tempo = coalesce(demographics.time_in_education_pratica,
                                            demographics.time_in_education_qualidade)) |>
    count_pct(tempo, "Years working in education")
) |> print(n = Inf)
# Out:
# # A tibble: 39 × 2
#    Characteristic                              Value
#    <chr>                                       <chr>
#  1 "Responding students (n = 741)"             ""
#  2 "  Age in years, M (SD)"                    "9.60 (1.15)"
#  3 "Sex"                                       ""
#  4 "  Feminino"                                "371 (50.1%)"
#  5 "  Masculino"                               "356 (48.0%)"
#  6 "  Other / prefer not to say"               "14 (1.9%)"
#  7 "People at home (excluding the student)"    ""
#  8 "  1 a 3"                                   "348 (47.0%)"
#  9 "  4 a 7"                                   "335 (45.2%)"
# 10 "  8 a 10"                                  "30 (4.0%)"
# 11 "  Mais de 10"                              "28 (3.8%)"
# 12 "Responding families (n = 912)"             ""
# 13 "Monthly family income"                     ""
# 14 "  Até 1 salário mínimo"                    "163 (17.9%)"
# 15 "  De 1 a 3 salários mínimos"               "362 (39.7%)"
# 16 "  De 3 a 6 salários mínimos"               "256 (28.1%)"
# 17 "  Mais de 6 salários mínimos"              "107 (11.7%)"
# 18 "  Nenhuma"                                 "24 (2.6%)"
# 19 "People at home (excluding the respondent)" ""
# 20 "  1 a 3"                                   "430 (47.1%)"
# 21 "  11 ou mais"                              "5 (0.5%)"
# 22 "  4 a 7"                                   "462 (50.7%)"
# 23 "  8 a 10"                                  "15 (1.6%)"
# 24 "Premature birth of the child"              ""
# 25 "  Não"                                     "812 (89.0%)"
# 26 "  Não tenho essa informação"               "11 (1.2%)"
# 27 "  Sim"                                     "89 (9.8%)"
# 28 "Child diagnosis"                           ""
# 29 "  Any diagnosis"                           "84 (9.2%)"
# 30 "  No diagnosis"                            "828 (90.8%)"
# 31 "Responding teachers (n = 111)"             ""
# 32 "Years working in education"                ""
# 33 "  De 1 a 3 anos"                           "16 (14.4%)"
# 34 "  De 12 a 15 anos"                         "11 (9.9%)"
# 35 "  De 3 a 6 anos"                           "26 (23.4%)"
# 36 "  De 6 a 9 anos"                           "15 (13.5%)"
# 37 "  De 9 a 12 anos"                          "14 (12.6%)"
# 38 "  acima de 15 anos"                        "20 (18.0%)"
# 39 "  até 1 ano"                               "9 (8.1%)"

# %% [markdown]
# ### Table 3 — Matched items, all respondents
#
# Item level means for students and families on the same content, before restricting to linked pairs.

# %%
# Table 3 - parallel items, student x family, all respondents
# item_summary: M (SD) for scale items; % Yes for the additional 0/1 questions
item_summary <- \(d, col, sec) if (sec == "behavior_matrix") msd(d[[col]]) else psim(d[[col]])

itens <- cb |>
  filter(survey_title == "Inventário de Saúde Emocional - Aluno",
         section_id %in% c("behavior_matrix", "yes_no_questions"), type %in% c("matrix", "select")) |>
  select(column_name, label, section_id)

# student and family items are complete: no analysis below loses cases
stopifnot(!anyNA(df_st[paste0(itens$column_name, "_num")]),
          !anyNA(df_par[paste0(itens$column_name, "_num")]))

itens |>
  rowwise() |>
  mutate(Student = item_summary(df_st, paste0(column_name, "_num"), section_id),
         Family = item_summary(df_par, paste0(column_name, "_num"), section_id)) |>
  ungroup() |>
  select(Item = label, Student, Family) |>
  print(n = Inf)
# Out:
# # A tibble: 18 × 3
#    Item                                                           Student Family
#    <chr>                                                          <chr>   <chr>
#  1 Quando você não consegue fazer uma atividade, consegue pedir … 3.72 (… 3.96 …
#  2 Quando seus colegas pensam diferente de você, você consegue d… 3.23 (… 3.72 …
#  3 Você consegue fazer amigos novos?                              4.24 (… 4.11 …
#  4 Quando algo ruim acontece, você consegue não ficar muito nerv… 2.67 (… 3.00 …
#  5 Consegue participar de atividade de grupo ou brincadeiras com… 4.03 (… 4.09 …
#  6 Quando sente raiva, tristeza ou alegria, você consegue se con… 3.09 (… 2.86 …
#  7 Consegue prestar atenção na explicação dos professores durant… 3.99 (… 3.73 …
#  8 Se alguém faz algo que você não gosta, consegue falar sobre o… 3.07 (… 3.46 …
#  9 Você consegue entender todas as matérias na escola?            3.62 (… 3.72 …
# 10 Quando você está triste ou não está bem, consegue contar isso… 3.87 (… 3.87 …
# 11 Consegue enfrentar um pensamento ruim que vem em sua cabeça?   3.36 (… 3.34 …
# 12 Gosta de ir para a escola?                                     77.6%   89.9%
# 13 Você sente dor de cabeça com frequência, mesmo quando não est… 48.3%   17.4%
# 14 Tem dificuldades para dormir?                                  37.2%   11.6%
# 15 Você se preocupa muito com coisas que ainda nem aconteceram?   64.1%   43.1%
# 16 Alguém já fez bullying com você nesta escola (já te machucou,… 51.3%   43.4%
# 17 Você fez bullying com alguém, mesmo sem querer (já machucou, … 21.3%   15.6%
# 18 Você já viu alguém sofrendo bullying nesta escola?             61.9%   49.6%

# %% [markdown]
# ### Table 4 — Matched items in the dyads
#
# Same items in the subsample where child and caregiver are linked, so the two reports refer to the same child.

# %%
# Table 4 - parallel items in the dyads (same child, same caregiver)
itens |>
  rowwise() |>
  mutate(Student = item_summary(df_dy, paste0(column_name, "_num_aluno"), section_id),
         Family = item_summary(df_dy, paste0(column_name, "_num_familia"), section_id)) |>
  ungroup() |>
  select(Item = label, Student, Family) |>
  print(n = Inf)
# Out:
# # A tibble: 18 × 3
#    Item                                                           Student Family
#    <chr>                                                          <chr>   <chr>
#  1 Quando você não consegue fazer uma atividade, consegue pedir … 3.76 (… 4.00 …
#  2 Quando seus colegas pensam diferente de você, você consegue d… 3.18 (… 3.74 …
#  3 Você consegue fazer amigos novos?                              4.27 (… 4.15 …
#  4 Quando algo ruim acontece, você consegue não ficar muito nerv… 2.75 (… 3.03 …
#  5 Consegue participar de atividade de grupo ou brincadeiras com… 4.05 (… 4.19 …
#  6 Quando sente raiva, tristeza ou alegria, você consegue se con… 3.13 (… 2.96 …
#  7 Consegue prestar atenção na explicação dos professores durant… 4.03 (… 3.76 …
#  8 Se alguém faz algo que você não gosta, consegue falar sobre o… 3.13 (… 3.42 …
#  9 Você consegue entender todas as matérias na escola?            3.64 (… 3.70 …
# 10 Quando você está triste ou não está bem, consegue contar isso… 3.96 (… 3.85 …
# 11 Consegue enfrentar um pensamento ruim que vem em sua cabeça?   3.45 (… 3.38 …
# 12 Gosta de ir para a escola?                                     79.3%   88.2%
# 13 Você sente dor de cabeça com frequência, mesmo quando não est… 47.5%   20.7%
# 14 Tem dificuldades para dormir?                                  38.7%   12.1%
# 15 Você se preocupa muito com coisas que ainda nem aconteceram?   67.2%   50.5%
# 16 Alguém já fez bullying com você nesta escola (já te machucou,… 49.0%   46.6%
# 17 Você fez bullying com alguém, mesmo sem querer (já machucou, … 18.2%   17.0%
# 18 Você já viu alguém sofrendo bullying nesta escola?             59.1%   59.4%

# %% [markdown]
# ### Tables 5 and 6 — Teacher instrument items
#
# Item level description of the two teacher inventories, reported separately because each has its own respondent set.

# %%
# Tables 5 and 6 - teacher instrument items
# In Practice Part 2 (matrix_2), '(0) cannot say' lies outside the 1-4 continuum: becomes NA
teacher_items <- function(d, survey, sections, zero_na = FALSE) cb |>
  filter(survey_title == survey, section_id %in% sections, type == "matrix") |>
  rowwise() |>
  mutate(v = list(na_if(d[[paste0(column_name, "_num")]] * 1, if (zero_na && section_id == "matrix_2") 0 else -1)),
         n = sum(!is.na(v)), `M (SD)` = msd(v)) |>
  ungroup() |>
  select(Item = label, Dimension = dimension, n, `M (SD)`)

teacher_items(filter(df_t, has_pratica), "INVENTÁRIO DE PRÁTICA PEDAGÓGICA E PERFIL DA TURMA",
           c("matrix_1", "matrix_2"), zero_na = TRUE) |>
  mutate(Dimension = if_else(str_detect(Dimension, "Não sei informar"), "", Dimension)) |>
  print(n = Inf)
teacher_items(filter(df_t, has_qualidade), "Inventário de Qualidade de Vida e Saúde Mental",
           "questions_matrix") |>
  print(n = Inf)
# Out:
# # A tibble: 21 × 4
#    Item                                                 Dimension     n `M (SD)`
#    <chr>                                                <chr>     <int> <chr>
#  1 Com que frequência você se considera capaz de estim… "Experiê…    90 4.02 (0…
#  2 Com que frequência você propõe atividades em que os… "Experiê…    90 3.91 (0…
#  3 Com que frequência os alunos têm espaço para expres… "Itens e…    90 4.18 (0…
#  4 Com que frequência você utiliza atividades em que o… "Itens e…    90 3.81 (0…
#  5 Com que frequência você propõe atividades que exige… "Itens e…    90 3.70 (0…
#  6 Com que frequência você adapta sua metodologia quan… "Itens e…    90 4.17 (0…
#  7 Com que frequência você incentiva os alunos a fazer… "Itens e…    90 4.38 (0…
#  8 Com que frequência você valoriza mais o processo de… "Itens e…    90 4.21 (0…
#  9 Com que frequência você pede que os alunos explique… "Itens e…    90 4.21 (0…
# 10 Com que frequência você ajusta o ritmo da aula de a… "Itens e…    90 4.20 (0…
# 11 Meus alunos parecem animados para vir à escola.      ""           87 2.89 (0…
# 12 Meus alunos se sentem seguros na escola onde trabal… ""           88 3.43 (0…
# 13 A escola onde trabalho é um ótimo lugar para os alu… ""           88 3.60 (0…
# 14 Meus alunos gostam das minhas aulas.                 ""           89 3.21 (0…
# 15 Meus alunos gostam de participar de discussões e at… ""           89 3.18 (0…
# 16 Meus alunos se sentem confiantes ao realizar as tar… ""           90 2.96 (0…
# 17 Acredito que ir bem na escola é importante para meu… ""           90 3.54 (0…
# 18 Os alunos da minha escola têm boas chances de se de… ""           89 3.58 (0…
# 19 Os alunos dessa turma demonstram comportamento saud… ""           89 2.72 (0…
# 20 Dos alunos dessa turma respeitam e valorizam a dive… ""           89 2.89 (0…
# 21 Os alunos desssa turma conseguem gerenciar suas emo… ""           89 2.40 (0…
# # A tibble: 49 × 4
#    Item                                                 Dimension     n `M (SD)`
#    <chr>                                                <chr>     <int> <chr>
#  1 Consegue lidar bem com frustrações e imprevistos? (… Saúde me…   102 3.78 (0…
#  2 Mantém o autocontrole em situações de estresse ou c… Saúde me…   102 3.89 (0…
#  3 Consegue ser assertivo sem elevar o tom de voz ou s… Saúde me…   102 3.80 (0…
#  4 Cobra demais de si mesmo(a)? (ex.: sentir que nunca… Saúde me…   102 3.99 (0…
#  5 Cobra demais dos outros? (ex.: esperar que as pesso… Saúde me…   102 3.15 (1…
#  6 Sofre por antecipação? (ex.: preocupar-se com algo … Saúde me…   102 3.70 (1…
# 40 Os colaboradores possuem as mesmas oportunidades? (… Clima or…    93 3.60 (1…
# 41 Este é um lugar psicologicamente saudável? (ex.: tr… Clima or…    93 3.60 (1…
# 42 Todos são bem tratados independentemente de diferen… Clima or…    93 4.22 (1…
# 43 Tem acesso aos equipamentoe e materiais  adequados … Clima or…    93 4.16 (0…
# 44 Sente-se à vontade para falar com sua liderança? (e… Liderança    93 3.91 (1…
# 45 Recebe feedback para melhorar seu desempenho? (ex.:… Liderança    93 3.76 (1…
# 46 Recebe treinamentos adequados? (ex.: aprender o nec… Liderança    93 3.83 (0…
# 47 Sua liderança demonstra preocupação com seu bem-est… Liderança    93 3.34 (1…
# 48 Sente-se valorizado(a) na empresa? (ex.: reconhecim… Satisfaç…    93 3.66 (1…
# 49 Tem orgulho em trabalhar nesta empresa? (ex.: falar… Satisfaç…    93 4.25 (1…

# %% [markdown]
# ### Table 7 — School comparison
#
# Tests whether the three schools differ on each dimension before results are pooled.

# %%
# Table 7 - school comparison: score = mean of the dimension's valid items (na.rm)
# Codebook dimensions assumed correct; the three frames already contain only the three schools
scores <- bind_rows(
  df_st |> mutate(Group = "Students", survey_title = "Inventário de Saúde Emocional - Aluno"),
  df_par |> mutate(Group = "Families", survey_title = "Inventário de Saúde Emocional - Família"),
  df_t |> filter(has_qualidade) |>
    mutate(Group = "Teachers (QoL)", survey_title = "Inventário de Qualidade de Vida e Saúde Mental")) |>
  pivot_longer(matches("^(behavior_matrix|questions_matrix)\\.\\d+_num$"),
               names_to = "column_name", values_to = "v", values_drop_na = TRUE) |>
  inner_join(cb |> filter(type == "matrix") |>
               transmute(survey_title, column_name = paste0(column_name, "_num"), dimension),
             by = c("survey_title", "column_name")) |>
  summarise(score = mean(v), .by = c(Group, dimension, school_name, respondent_id))

scores |>
  summarise(ms = msd(score), .by = c(Group, dimension, school_name)) |>
  pivot_wider(names_from = school_name, values_from = ms) |>
  left_join(scores |>
              nest(.by = c(Group, dimension)) |>
              mutate(fit = map(data, \(d) aov(score ~ school_name, d)),
                     eta2 = map_dbl(fit, \(m) eta_squared(m, partial = FALSE, ci = NULL)$Eta2),
                     stats = map(fit, \(m) tidy(m)[1, c("statistic", "p.value")])) |>
              unnest(stats) |>
              transmute(Group, dimension, F = sprintf("%.2f", statistic),
                        p = sprintf("%.3f", p.value), eta2 = sprintf("%.3f", eta2)),
            by = c("Group", "dimension")) |>
  rename(Dimension = dimension) |>
  print(n = Inf, width = Inf)  # eta2 column would be elided at the default width
# Out:
# # A tibble: 12 × 8
#    Group          Dimension                   `O SEMEADOR` `Futuro Brilhante`
#    <chr>          <chr>                       <chr>        <chr>
#  1 Students       Autoeficácia Emocional      3.35 (0.77)  3.32 (0.83)
#  2 Students       Autoeficácia Social         3.63 (0.76)  3.65 (0.78)
#  3 Students       Autoeficácia Acadêmica      3.77 (0.98)  3.78 (1.00)
#  4 Families       Autoeficácia Emocional      3.44 (0.71)  3.39 (0.72)
#  5 Families       Autoeficácia Social         3.86 (0.73)  3.89 (0.67)
#  6 Families       Autoeficácia Acadêmica      3.75 (0.87)  3.65 (1.00)
#  7 Teachers (QoL) Saúde mental                2.83 (0.50)  3.05 (0.44)
#  8 Teachers (QoL) Autonomia                   3.98 (0.64)  4.19 (0.43)
#  9 Teachers (QoL) Relacionamento e Cooperação 3.43 (0.48)  3.58 (0.35)
# 10 Teachers (QoL) Clima organizacional        4.01 (0.70)  4.35 (0.52)
# 11 Teachers (QoL) Liderança                   3.86 (0.85)  4.06 (0.78)
# 12 Teachers (QoL) Satisfação com a empresa    4.05 (0.86)  4.37 (0.55)
#    `Marton Lucca` F     p     eta2
#    <chr>          <chr> <chr> <chr>
#  1 3.38 (0.82)    0.17  0.848 0.000
#  2 3.66 (0.72)    0.08  0.920 0.000
#  3 4.01 (0.90)    2.08  0.126 0.006
#  4 3.20 (0.71)    3.84  0.022 0.008
#  5 3.60 (0.79)    4.94  0.007 0.011
#  6 3.72 (0.90)    0.82  0.439 0.002
#  7 2.78 (0.51)    3.03  0.053 0.058
#  8 3.86 (0.82)    1.86  0.162 0.040
#  9 3.02 (0.59)    10.37 0.000 0.187
# 10 3.32 (1.01)    13.30 0.000 0.228
# 11 3.20 (0.86)    8.44  0.000 0.158
# 12 3.43 (1.22)    7.73  0.001 0.147

# %% [markdown]
# ### Tables S1 and S2 — CFA of the codebook structure
#
# Tests the structure the instrument was designed with; baseline against which the two factor model of Part B is judged.

# %%
# Tables S1 and S2 - CFA of the structure proposed in the codebook (dimensions assumed correct)
# Model: one factor per codebook dimension, items renamed i<item_id>
# cfa_items(survey, section): codebook items of a matrix section (model name, data column, label, dimension)
cfa_items <- \(survey, section) cb |>
  filter(survey_title == survey, section_id == section, type == "matrix") |>
  transmute(vs = paste0("i", item_id), col = paste0(column_name, "_num"), label, dimension)
# cfa_syntax(items): lavaan model string, one factor per dimension
cfa_syntax <- \(items) items |>
  summarise(eq = paste(make.names(first(dimension)), "=~", paste(vs, collapse = " + ")), .by = dimension) |>
  pull(eq) |> paste(collapse = "\n")

it_st <- cfa_items("Inventário de Saúde Emocional - Aluno", "behavior_matrix")
it_par <- cfa_items("Inventário de Saúde Emocional - Família", "behavior_matrix")
it_t <- cfa_items("Inventário de Qualidade de Vida e Saúde Mental", "questions_matrix")
m_st <- cfa_syntax(it_st); m_par <- cfa_syntax(it_par); m_t <- cfa_syntax(it_t)
cat(m_st, m_par, m_t, sep = "\n\n")
# Out:
# Autoeficácia.Emocional =~ i1 + i4 + i6 + i10 + i11
# Autoeficácia.Social =~ i2 + i3 + i5 + i8
# Autoeficácia.Acadêmica =~ i7 + i9
#
# Autoeficácia.Emocional =~ i1 + i4 + i6 + i10 + i11
# Autoeficácia.Social =~ i2 + i3 + i5 + i8
# Autoeficácia.Acadêmica =~ i7 + i9
#
# Saúde.mental =~ i1 + i2 + i3 + i4 + i5 + i6 + i7 + i8 + i9 + i10 + i11 + i12 + i13 + i14 + i15 + i16 + i17 + i18 + i19 + i20 + i21 + i22 + i23 + i24 + i25 + i26 + i27 + i28 + i29 + i30 + i31
# Autonomia =~ i32 + i33 + i34 + i35
# Relacionamento.e.Cooperação =~ i36 + i37 + i38 + i39
# Clima.organizacional =~ i40 + i41 + i42 + i43
# Liderança =~ i44 + i45 + i46 + i47
# Satisfação.com.a.empresa =~ i48 + i49

# %%
# Run: WLSMV (ordinal indicators), listwise complete cases. Student and family items are complete;
# QoL respondents who stopped mid inventory are dropped (n reported in the table label)
# cfa_data(d, items): section items renamed to the model names, complete cases only
cfa_data <- \(d, items) d |> select(all_of(set_names(items$col, items$vs))) |> drop_na()
fit_st <- cfa(m_st, cfa_data(df_st, it_st), ordered = TRUE, estimator = "WLSMV")
fit_par <- cfa(m_par, cfa_data(df_par, it_par), ordered = TRUE, estimator = "WLSMV")
fit_t <- cfa(m_t, cfa_data(filter(df_t, has_qualidade), it_t), ordered = TRUE, estimator = "WLSMV")
# Out:
# Warning message:
# "lavaan->lav_model_vcov():
#    The variance-covariance matrix of the estimated parameters (vcov) does not
#    appear to be positive definite! The smallest eigenvalue (= -4.140719e-15)
#    is smaller than zero. This may be a symptom that the model is not
#    identified."
# Warning message:
# "lavaan->lav_object_post_check():
#    covariance matrix of latent variables is not positive definite ; use
#    lavInspect(fit, "cov.lv") to investigate."

# %%
# Summary: Table S1 (scaled fit indices) and Table S2 (standardized loadings)
# cfa_tables(fit, items, model): list(fit_row, loadings) for one fitted model
cfa_tables <- \(fit, items, model) list(
  fit_row = fitMeasures(fit, c("chisq.scaled", "df", "cfi.scaled", "tli.scaled",
                               "rmsea.scaled", "rmsea.ci.lower.scaled", "rmsea.ci.upper.scaled", "srmr")) |>
    (\(fm) tibble(Model = sprintf("%s (n = %d)", model, lavInspect(fit, "nobs")),
                  chi2_df = sprintf("%.1f (%d)", fm[1], fm[2]), CFI = sprintf("%.3f", fm[3]),
                  TLI = sprintf("%.3f", fm[4]), RMSEA = sprintf("%.3f [%.3f, %.3f]", fm[5], fm[6], fm[7]),
                  SRMR = sprintf("%.3f", fm[8])))(),
  loadings = standardizedSolution(fit) |> filter(op == "=~") |>
    left_join(select(items, vs, label, dimension), by = c("rhs" = "vs")) |>
    transmute(Model = sprintf("%s (n = %d)", model, lavInspect(fit, "nobs")), Factor = dimension,
              Item = label, Loading = sprintf("%.2f", est.std)))

models <- list(cfa_tables(fit_st, it_st, "Students: self efficacy, 3 factors"),
               cfa_tables(fit_par, it_par, "Families: self efficacy, 3 factors"),
               cfa_tables(fit_t, it_t, "Teachers QoL: 6 factors"))
map_dfr(models, "fit_row") |> as.data.frame() |> print()
map_dfr(models, "loadings") |> as.data.frame() |> print()
# Out:
#                                          Model       chi2_df   CFI   TLI
# 1 Students: self efficacy, 3 factors (n = 741)    207.5 (41) 0.906 0.873
# 2 Families: self efficacy, 3 factors (n = 912)    597.0 (41) 0.914 0.885
# 3             Teachers QoL: 6 factors (n = 93) 1429.3 (1112) 0.918 0.914
#                  RMSEA  SRMR
# 1 0.074 [0.064, 0.084] 0.057
# 2 0.122 [0.113, 0.131] 0.063
# 3 0.056 [0.047, 0.064] 0.110
#                                           Model                      Factor
# 1  Students: self efficacy, 3 factors (n = 741)      Autoeficácia Emocional
# 2  Students: self efficacy, 3 factors (n = 741)      Autoeficácia Emocional
# 3  Students: self efficacy, 3 factors (n = 741)      Autoeficácia Emocional
# 4  Students: self efficacy, 3 factors (n = 741)      Autoeficácia Emocional
# 5  Students: self efficacy, 3 factors (n = 741)      Autoeficácia Emocional
# 6  Students: self efficacy, 3 factors (n = 741)         Autoeficácia Social
# 7  Students: self efficacy, 3 factors (n = 741)         Autoeficácia Social
# 8  Students: self efficacy, 3 factors (n = 741)         Autoeficácia Social
# 9  Students: self efficacy, 3 factors (n = 741)         Autoeficácia Social
# 10 Students: self efficacy, 3 factors (n = 741)      Autoeficácia Acadêmica
# 11 Students: self efficacy, 3 factors (n = 741)      Autoeficácia Acadêmica
# 12 Families: self efficacy, 3 factors (n = 912)      Autoeficácia Emocional
# 13 Families: self efficacy, 3 factors (n = 912)      Autoeficácia Emocional
# 14 Families: self efficacy, 3 factors (n = 912)      Autoeficácia Emocional
# 15 Families: self efficacy, 3 factors (n = 912)      Autoeficácia Emocional
# 16 Families: self efficacy, 3 factors (n = 912)      Autoeficácia Emocional
# 17 Families: self efficacy, 3 factors (n = 912)         Autoeficácia Social
# 18 Families: self efficacy, 3 factors (n = 912)         Autoeficácia Social
# 19 Families: self efficacy, 3 factors (n = 912)         Autoeficácia Social
# 20 Families: self efficacy, 3 factors (n = 912)         Autoeficácia Social
# 21 Families: self efficacy, 3 factors (n = 912)      Autoeficácia Acadêmica
# 22 Families: self efficacy, 3 factors (n = 912)      Autoeficácia Acadêmica
# 23             Teachers QoL: 6 factors (n = 93)                Saúde mental
# 24             Teachers QoL: 6 factors (n = 93)                Saúde mental
# 25             Teachers QoL: 6 factors (n = 93)                Saúde mental
# 26             Teachers QoL: 6 factors (n = 93)                Saúde mental
# 27             Teachers QoL: 6 factors (n = 93)                Saúde mental
# 28             Teachers QoL: 6 factors (n = 93)                Saúde mental
# 29             Teachers QoL: 6 factors (n = 93)                Saúde mental
# 30             Teachers QoL: 6 factors (n = 93)                Saúde mental
# 31             Teachers QoL: 6 factors (n = 93)                Saúde mental
# 32             Teachers QoL: 6 factors (n = 93)                Saúde mental
# 33             Teachers QoL: 6 factors (n = 93)                Saúde mental
# 34             Teachers QoL: 6 factors (n = 93)                Saúde mental
# 35             Teachers QoL: 6 factors (n = 93)                Saúde mental
# 36             Teachers QoL: 6 factors (n = 93)                Saúde mental
# 37             Teachers QoL: 6 factors (n = 93)                Saúde mental
# 38             Teachers QoL: 6 factors (n = 93)                Saúde mental
# 39             Teachers QoL: 6 factors (n = 93)                Saúde mental
# 40             Teachers QoL: 6 factors (n = 93)                Saúde mental
# 41             Teachers QoL: 6 factors (n = 93)                Saúde mental
# 42             Teachers QoL: 6 factors (n = 93)                Saúde mental
# 43             Teachers QoL: 6 factors (n = 93)                Saúde mental
# 44             Teachers QoL: 6 factors (n = 93)                Saúde mental
# 45             Teachers QoL: 6 factors (n = 93)                Saúde mental
# 46             Teachers QoL: 6 factors (n = 93)                Saúde mental
# 47             Teachers QoL: 6 factors (n = 93)                Saúde mental
# 48             Teachers QoL: 6 factors (n = 93)                Saúde mental
# 49             Teachers QoL: 6 factors (n = 93)                Saúde mental
# 50             Teachers QoL: 6 factors (n = 93)                Saúde mental
# 51             Teachers QoL: 6 factors (n = 93)                Saúde mental
# 52             Teachers QoL: 6 factors (n = 93)                Saúde mental
# 53             Teachers QoL: 6 factors (n = 93)                Saúde mental
# 54             Teachers QoL: 6 factors (n = 93)                   Autonomia
# 55             Teachers QoL: 6 factors (n = 93)                   Autonomia
# 56             Teachers QoL: 6 factors (n = 93)                   Autonomia
# 57             Teachers QoL: 6 factors (n = 93)                   Autonomia
# 58             Teachers QoL: 6 factors (n = 93) Relacionamento e Cooperação
# 59             Teachers QoL: 6 factors (n = 93) Relacionamento e Cooperação
# 60             Teachers QoL: 6 factors (n = 93) Relacionamento e Cooperação
# 61             Teachers QoL: 6 factors (n = 93) Relacionamento e Cooperação
# 62             Teachers QoL: 6 factors (n = 93)        Clima organizacional
# 63             Teachers QoL: 6 factors (n = 93)        Clima organizacional
# 64             Teachers QoL: 6 factors (n = 93)        Clima organizacional
# 65             Teachers QoL: 6 factors (n = 93)        Clima organizacional
# 66             Teachers QoL: 6 factors (n = 93)                   Liderança
# 67             Teachers QoL: 6 factors (n = 93)                   Liderança
# 68             Teachers QoL: 6 factors (n = 93)                   Liderança
# 69             Teachers QoL: 6 factors (n = 93)                   Liderança
# 70             Teachers QoL: 6 factors (n = 93)    Satisfação com a empresa
# 71             Teachers QoL: 6 factors (n = 93)    Satisfação com a empresa
#                                                                                                                          Item
# 1                                            Quando você não consegue fazer uma atividade, consegue pedir ajuda ao professor?
# 2                                               Quando algo ruim acontece, você consegue não ficar muito nervoso ou irritado?
# 3                                   Quando sente raiva, tristeza ou alegria, você consegue se controlar sem chorar ou brigar?
# 4                              Quando você está triste ou não está bem, consegue contar isso para um amigo ou para seus pais?
# 5                                                                Consegue enfrentar um pensamento ruim que vem em sua cabeça?
# 6                                  Quando seus colegas pensam diferente de você, você consegue dizer o que pensa mesmo assim?
# 7                                                                                           Você consegue fazer amigos novos?
# 8                                     Consegue participar de atividade de grupo ou brincadeiras com seus colegas, sem brigar?
# 9                              Se alguém faz algo que você não gosta, consegue falar sobre o que sente e pensa para a pessoa?
# 10                                                   Consegue prestar atenção na explicação dos professores durante as aulas?
# 11                                                                        Você consegue entender todas as matérias na escola?
# 12                                                   Quando seu(a) filho(a) não consegue fazer uma atividade, ele pede ajuda?
# 13                                            Quando algo ruim acontece, ele(a) consegue não ficar muito nervoso ou irritado?
# 14                                   Quando sente raiva, tristeza ou medo, ele(a) consegue se controlar sem chorar ou brigar?
# 15                                         Quando ele(a) está triste ou não está bem, consegue conversar com você sobre isso?
# 16                                                                              Ele(a) consegue enfrentar um pensamento ruim?
# 17                                      Quando alguém pensa diferente dele(a), ele(a) consegue dizer o que pensa mesmo assim?
# 18                                                                               Ele(a) tem facilidade em fazer amigos novos?
# 19                                    Consegue participar de atividade de grupo ou brincadeiras com seus colegas, sem brigar?
# 20                           Se alguém faz algo que ele(a) não gosta, consegue falar sobre o que sente e pensa para a pessoa?
# 21                                                  Ele(a) consegue prestar atenção quando está fazendo as tarefas da escola?
# 22                                                                      Ele(a) consegue entender todas as matérias na escola?
# 23                   Consegue lidar bem com frustrações e imprevistos? (ex.: manter a calma mesmo quando não cumpre um prazo)
# 24                       Mantém o autocontrole em situações de estresse ou conflito? (ex.: não perder a cabeça em discussões)
# 25                     Consegue ser assertivo sem elevar o tom de voz ou ser agressivo? (ex.: falar o que precisa sem gritar)
# 26                                                      Cobra demais de si mesmo(a)? (ex.: sentir que nunca fez o suficiente)
# 27                                                      Cobra demais dos outros? (ex.: esperar que as pessoas ajam como você)
# 28                                                Sofre por antecipação? (ex.: preocupar-se com algo que ainda nem aconteceu)
# 29                                                Remói situações do passado? (ex.: lembrar com frequência de mágoas antigas)
# 30                                                                              Valoriza excessivamente a opinião dos outros?
# 31                                                                 Sente algum tipo de fobia? (ex.: medo de falar em público)
# 32                                                                                     Considera-se tímido(a) ou inseguro(a)?
# 33         Tem dificuldade em conviver com pessoas mais lentas? (ex.: ficar irritado quando alguém demora para entender algo)
# 68                                      Recebe treinamentos adequados? (ex.: aprender o necessário para cumprir suas funções)
# 69                    Sua liderança demonstra preocupação com seu bem-estar? (ex.: perguntar como você está e oferecer apoio)
# 70                                                  Sente-se valorizado(a) na empresa? (ex.: reconhecimento pelos resultados)
# 71                                      Tem orgulho em trabalhar nesta empresa? (ex.: falar bem do local para outras pessoas)
#    Loading
# 1     0.63
# 2     0.38
# 3     0.51
# 4     0.50
# 5     0.44
# 6     0.39
# 7     0.41
# 8     0.52
# 9     0.46
# 10    0.80
# 11    0.69
# 12    0.70
# 13    0.54
# 14    0.63
# 15    0.68
# 16    0.66
# 17    0.72
# 18    0.54
# 19    0.64
# 20    0.71
# 21    0.83
# 22    0.84
# 23    0.66
# 24    0.68
# 25    0.14
# 26   -0.09
# 27   -0.32
# 28   -0.49
# 29   -0.69
# 30   -0.13
# 31   -0.53
# 32   -0.28
# 33   -0.43
# 34   -0.52
# 35   -0.75
# 36   -0.54
# 37   -0.63
# 38   -0.72
# 39   -0.47
# 40   -0.75
# 41   -0.82
# 42   -0.54
# 43   -0.61
# 44   -0.42
# 45   -0.75
# 46   -0.59
# 47   -0.54
# 48   -0.72
# 49   -0.57
# 50   -0.81
# 51   -0.64
# 52   -0.87
# 53    0.57
# 54    0.74
# 55    0.77
# 56    0.48
# 57    0.86
# 58    0.72
# 59    0.93
# 60    0.93
# 61   -0.75
# 62    0.77
# 63    0.90
# 64    0.73
# 65    0.75
# 66    0.91
# 67    0.76
# 68    0.64
# 69    0.89
# 70    0.84
# 71    0.91

# %% [markdown]
# ### Table S3 — Enrolled and respondents per school and class
#
# Class level breakdown of Table 1, including the Practice teachers linked to each class.

# %%
# Table S3 - enrolled and respondents per school and class; Practice teachers
# linked through 'class evaluated' (class_evaluated = students'/families' class_id)
bind_rows(mutate(roster, turma = "(all classes)"), roster) |>
  count(escola, turma, name = "N") |>
  left_join(bind_rows(mutate(df_st, class_name = "(all classes)"), df_st) |>
              count(escola = school_name, turma = class_name, name = "aluno"), by = c("escola", "turma")) |>
  left_join(bind_rows(mutate(df_par, class_name = "(all classes)"), df_par) |>
              count(escola = school_name, turma = class_name, name = "familia"), by = c("escola", "turma")) |>
  left_join(df_t |> filter(has_pratica) |>
              inner_join(distinct(bind_rows(df_st, df_par), class_id, escola = school_name, turma = class_name),
                         by = c("demographics.class_evaluated" = "class_id")) |>
              count(escola, turma, name = "prof_pratica"), by = c("escola", "turma")) |>
  arrange(escola, turma != "(all classes)", turma) |>
  mutate(across(c(aluno, familia, prof_pratica), \(x) replace_na(x, 0L)),
         `Student n (%)` = npct(aluno, N), `Family n (%)` = npct(familia, N)) |>
  select(School = escola, Class = turma, `N enrolled` = N, `Student n (%)`, `Family n (%)`,
         `Teacher (Practice), n` = prof_pratica) |>
  print(n = Inf)
# Out:
# # A tibble: 75 × 6
#    School           Class         `N enrolled` `Student n (%)` `Family n (%)`
#    <chr>            <chr>                <int> <chr>           <chr>
